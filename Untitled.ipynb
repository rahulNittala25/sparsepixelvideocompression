# %%
from importlib import reload

# %load_ext autoreload

# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %pip install tensorboardX
# %pip install av
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 5.3 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 28.2 MB 76.4 MB/s
# ...

# %%
# !wget --no-check-certificate https://www.crcv.ucf.edu/data/UCF101/UCF101.rar
# !unrar x "/content/UCF101.rar"
# !rm -rf "/content/UCF101.rar"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# %cd /content/drive/MyDrive/HLCV_project/
# Out:
# /content/drive/MyDrive/HLCV_project

# %%
import os
import shutil

f = open("./Dataset/annotations/remove.txt", "r")
a = f.read()
b = a.split("\n")

folders = []
for entry in b:
  first,act = entry.split(" ")
  folders.append(act)
root_path = "/content/UCF-101"
for folder in folders:
  pth = os.path.join(root_path,folder)
  shutil.rmtree(pth)

# %%
from trainer1 import Trainer
# from tester import Tester
from data_loader import Data_Loader
from torch.backends import cudnn
from utils import make_folder
from parameter import get_parameters

import os
import torch


##### Import libary for dataloader #####
##### https://github.com/kenshohara/3D-ResNets-PyTorch/blob/master/main.py
from Dataloader.transform.spatial_transforms import (
    Compose, VideoRandomCrop, RandomHorizontalFlip, ToTensor)
# from Dataloader.transform.temporal_transforms import LoopPadding, TemporalRandomCrop
# from Dataloader.transform.target_transforms import ClassLabel, VideoID
# from Dataloader.transform.target_transforms import Compose as TargetCompose
from Dataloader.dataloader import get_training_set, get_validation_set, get_test_set
from Dataloader.mean import get_mean
from torchvision.datasets import UCF101

# %%
class CONFIG():
    def __init__(self):
        self.model='dvd-gan'
        self.adv_loss='hinge'
        self.imsize=128
        self.g_num=5
        self.g_chn=32
        self.z_dim=120
        self.ds_chn=32 # SpatialDiscriminator channel
        self.dt_chn=32 # TemporalDiscriminator channel
        self.g_conv_dim=64
        self.d_conv_dim=64
        self.lambda_gp=10.0
        self.lr_schr='const'
        self.version=''

            # Training setting
        self.total_epoch=10
        self.d_iters=1
        self.g_iters=1
        self.batch_size=2
        self.num_workers=1
        self.g_lr=5e-5
        self.d_lr=5e-5
        self.lr_decay=0.9999
        self.beta1=0.0
        self.beta2=0.9

            # using pretrained
        self.pretrained_model = 13000

            # Misc
        self.train=True
        self.parallel=False
        self.gpus=["0"]
        self.dataset='ucf101'
        self.use_tensorboard=False
        self.n_class=101
        self.k_sample=64
        self.n_frames=24
        self.test_batch_size=8

            # Path
        self.image_path='./data'
        self.log_path='./logs'
        self.model_save_path='/content/models'
        self.sample_path='./samples'

            # epoch size
        self.log_epoch=1
        self.sample_epoch=20
        self.model_save_epoch=1000

            # Dataloader
        self.norm_value=255
        self.no_mean_norm=True
        self.std_norm=False
        self.mean_dataset='activitynet'
        self.root_path='/tmp4/potter/UCF101'
        self.video_path='videos_jpeg'
        self.annotation_path='annotations/ucf101_01.json'
        self.train_crop='none'
        self.sample_size=64

        self.initial_scale=1.0
        self.n_scales=5
        self.scale_step=0.84089641525
        self.density = 0.05

# %%
config = CONFIG()


config.dataset = 'ucf101'
config.video_path = "videos_jpeg"
config.adv_loss = 'hinge'
config.parallel = True
config.gpus = ["0"]
config.num_workers = 1
config.use_tensorboard = True 
config.ds_chn = 32 
config.dt_chn = 32 
config.g_chn = 32 
config.n_frames = 8 
config.k_sample = 4 
config.batch_size = 2
config.g_lr = 5e-4 
config.d_lr = 5e-5 
config.n_class = 1 
config.lr_schr = "const"
config.n_class = 2
config.root_path = "/content/UCF-101"
config.annotation_path = "/content/ucfTrainTestlist"
config.log_path = "./output_small_new/logs"
config.model_save_path = "./outputs_small_new/modelsZ"
config.sample_path = "./outputs/samples"
config.train_crop == 'none'
# Out:
# True

# %%
def custom_collate(batch):
    filtered_batch = []
    for video, _, _ in batch:
        filtered_batch.append(video)
    return torch.utils.data.dataloader.default_collate(filtered_batch)



cudnn.benchmark = True

##### Dataloader #####
config.mean = get_mean(config.norm_value, dataset=config.mean_dataset)

# if config.no_mean_norm and not config.std_norm:
#     norm_method = Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
# elif not config.std_norm:
#     norm_method = Normalize(config.mean, [1, 1, 1])

if config.train:
    spatial_transform = Compose([ToTensor(), VideoRandomCrop(128), RandomHorizontalFlip()]) 
    temporal_transform = None
    target_transform = None

    print("="*30,"\nLoading data...")
    training_data = UCF101("/content/UCF-101", "/content/drive/MyDrive/HLCV_project/Dataset/annotations", frames_per_clip=20,
                       step_between_clips=1, train=True, output_format="TCHW", transform=spatial_transform)
    train_loader = torch.utils.data.DataLoader(
            training_data,
            batch_size=config.batch_size,
            collate_fn=custom_collate,
            shuffle=True,
            num_workers=config.num_workers,
            pin_memory=True)
else:
    spatial_transform = Compose([
        Scale(config.sample_size),
        CenterCrop(config.sample_size),
        ToTensor(config.norm_value), norm_method
    ])
    temporal_transform = LoopPadding(config.n_frames)
    target_transform = ClassLabel()
    validation_data = get_validation_set(
        config, spatial_transform, temporal_transform, target_transform)
    val_loader = torch.utils.data.DataLoader(
        validation_data,
        batch_size=config.batch_size,
        collate_fn=custom_collate,
        shuffle=False,
        num_workers=config.num_workers,
        pin_memory=True)
# Out:
# ...
# Loading data...
#   0%|          | 0/169 [00:00<?, ?it/s]

# %%
make_folder(config.model_save_path, config.version)
make_folder(config.log_path, config.version)

# %%
config.total_epoch=5
trainer = Trainer(train_loader, config) 
trainer.train()
# Out:
# ...
# Build_model...
# Model building done!
# load_pretrained_model...
# loaded trained models (step: 13000)..!
# Inside the trainer!
# /usr/local/lib/python3.7/dist-packages/torchvision/io/video.py:162: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")
# Iterator created!
# steps per epoch: 147979
# ...
# Start training...
# 13200
# DS_Loss:tensor(2.0015, device='cuda:0', grad_fn=<AddBackward0>)
# DT_Loss:tensor(2.0434, device='cuda:0', grad_fn=<AddBackward0>)
# Selected Density:tensor(-0.0007, device='cuda:0', grad_fn=<SubBackward0>)
# DS_Loss:tensor(1.1381, device='cuda:0', grad_fn=<MeanBackward0>) DT_Loss:tensor(0.9837, device='cuda:0', grad_fn=<MeanBackward0>) MSE_Loss:tensor(0.0405, device='cuda:0', grad_fn=<MseLossBackward0>) Density_Loss:tensor(0.0018, device='cuda:0', grad_fn=<MulBackward0>)
# 13400
# ...

# %%
class DSET:
    def __init__(self, video_path='./Dataset/UCF101/videos_jpeg', annotation_path = "./Dataset/UCF101/annotations/ucf101_01.json"):
        self.dataset = 'ucf101'
        self.video_path = video_path
        self.annotation_path = annotation_path

# %%
spatial_transform = Compose([
            RandomHorizontalFlip(),
            ToTensor(1)
        ])
config = DSET()
training_data = get_training_set(config, spatial_transform, None, None)
# Out:
# dataset loading [0/9537]
# dataset loading [1000/9537]
# dataset loading [2000/9537]
# dataset loading [3000/9537]
# dataset loading [4000/9537]
# dataset loading [5000/9537]
# dataset loading [6000/9537]
# dataset loading [7000/9537]
# dataset loading [8000/9537]
# dataset loading [9000/9537]

# %%
import torch
train_loader = torch.utils.data.DataLoader(
            training_data,
            batch_size=1,
            shuffle=True,
            num_workers=1,
            pin_memory=True)

# %%
count = 0
data_iter = iter(train_loader)
while(True):
    count+=1
    print(count)
    try:
        real_videos, _ = next(data_iter)
    except:
        data_iter = iter(train_loader)
        real_videos, _ = next(data_iter)
# Out:
# 1
# 2

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

class Binarization(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self,x):
        return torch.round(x)

    def backward(self, x):
        return x

class Mask_Generator_Net(nn.Module):
    def __init__(self, in_channels=6):
        super().__init__()
        ###### C-Block Stacking ##########
        self.l11 = nn.Conv2d(in_channels, 64, 5, padding='same')
        self.l12 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=2)
        self.l13 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=5)
        self.d1 = nn.MaxPool2d(2)
        self.l21 = nn.Conv2d(128, 64, 5, padding='same')
        self.l22 = nn.Conv2d(128, 32, 5, padding='same', dilation=2)
        self.l23 = nn.Conv2d(128, 32, 5, padding='same', dilation=5)
        self.d2 = nn.MaxPool2d(2)
        self.l31 = nn.Conv2d(128, 128, 5, padding='same')
        self.l32 = nn.Conv2d(128, 64, 5, padding='same', dilation=2)
        self.l33 = nn.Conv2d(128, 64, 5, padding='same', dilation=5)
        self.d3 = nn.MaxPool2d(2)
        self.l41 = nn.Conv2d(256, 128, 5, padding='same')
        self.l42 = nn.Conv2d(256, 64, 5, padding='same', dilation=2)
        self.l43 = nn.Conv2d(256, 64, 5, padding='same', dilation=5)
        self.d4 = nn.MaxPool2d(2)
        self.l51 = nn.Conv2d(256, 256, 5, padding='same')
        self.l52 = nn.Conv2d(256, 128, 5, padding='same', dilation=2)
        self.l53 = nn.Conv2d(256, 128, 5, padding='same', dilation=5)
        self.convBlstm = ConvBLSTM(512, 512, (5,5), 1, batch_first=True)
        self.u1 = nn.Upsample(scale_factor=2)
        ###### TC-Block Stacking ##########
        self.tl11 = nn.ConvTranspose2d(256+512, 128, 5, padding=2)
        self.tl12 = nn.ConvTranspose2d(256+512, 64, 5, dilation=2, padding=4)
        self.tl13 = nn.ConvTranspose2d(256+512, 64, 5, dilation=5, padding=10)
        self.u2 = nn.Upsample(scale_factor=2)
        self.tl21 = nn.ConvTranspose2d(256+256, 128, 5, padding=2)
        self.tl22 = nn.ConvTranspose2d(256+256, 64, 5, dilation=2, padding=4)
        self.tl23 = nn.ConvTranspose2d(256+256, 64, 5, dilation=5, padding=10)
        self.u3 = nn.Upsample(scale_factor=2)
        self.tl31 = nn.ConvTranspose2d(256+128, 64, 5, padding=2)
        self.tl32 = nn.ConvTranspose2d(256+128, 32, 5, padding=4, dilation=2)
        self.tl33 = nn.ConvTranspose2d(256+128, 32, 5, padding=10, dilation=5)
        self.u4 = nn.Upsample(scale_factor=2)
        self.tl41 = nn.ConvTranspose2d(128+128, 64, 5, padding=2)
        self.tl42 = nn.ConvTranspose2d(128+128, 32, 5, padding=4, dilation=2)
        self.tl43 = nn.ConvTranspose2d(128+128, 32, 5, padding=10, dilation=5)
        ###### Conv Layer Stacking ##########
        self.conv1 = nn.ConvTranspose2d(128+in_channels,8, 3, padding=1)
        self.conv2 = nn.ConvTranspose2d(8, 1, 3, padding=1)
        self.conva2 = nn.Hardsigmoid()
        self.mask = Binarization()

    def forward(self, x):
        #### Conv Block 1
        B,T,C,H,W = x.shape
        x = x.view(B*T,C,H,W)
        x11 = F.elu(self.l11(x))
        x12 = F.elu(self.l12(x))
        x13 = F.elu(self.l13(x))
        x1o = torch.cat([x11,x12,x13], dim=1)
        x1 = self.d1(x1o)
        #### Conv Block 2
        x21 = F.elu(self.l21(x1))
        x22 = F.elu(self.l22(x1))
        x23 = F.elu(self.l23(x1))
        x2o = torch.cat([x21,x22,x23], dim=1)
        x2 = self.d2(x2o)
        #### Conv Block 3
        x31 = F.elu(self.l31(x2))
        x32 = F.elu(self.l32(x2))
        x33 = F.elu(self.l33(x2))
        x3o = torch.cat([x31,x32,x33], dim=1)
        x3 = self.d3(x3o)
        #### Conv Block 4
        x41 = F.elu(self.l41(x3))
        x42 = F.elu(self.l42(x3))
        x43 = F.elu(self.l43(x3))
        x4o = torch.cat([x41,x42,x43], dim=1)
        x4 = self.d4(x4o)
        #### Conv Block 5
        x51 = F.elu(self.l51(x4))
        x52 = F.elu(self.l52(x4))
        x53 = F.elu(self.l53(x4))
        x5o = torch.cat([x51,x52,x53], dim=1)
        t,n,h,w = x5o.shape
        x5 = x5o.view(1, t, n, h, w)
        #### ConvBiLSTM
        x_temp = self.convBlstm(x5,torch.flip(x5,[1]))
        _, t,n,h,w = x_temp.shape
        x_resized = x_temp.view(t,n,h,w)
        x_lstm = self.u1(x_resized)       
        #### Tr-Conv Block 1
        y1c = torch.cat([x_lstm, x4o], dim=1)
        y11 = F.elu(self.tl11(y1c))
        y12 = F.elu(self.tl12(y1c))
        y13 = F.elu(self.tl13(y1c))
        y1o = torch.cat([y11, y12, y13], dim=1)
        y2 = self.u2(y1o)
        #### Tr-Conv Block 2
        y2c = torch.cat([y2, x3o], dim=1)
        y21 = F.elu(self.tl21(y2c))
        y22 = F.elu(self.tl22(y2c))
        y23 = F.elu(self.tl23(y2c))
        y2o = torch.cat([y21, y22, y23], dim=1)
        y3 = self.u3(y2o)
        #### Tr-Conv Block 3
        y3c = torch.cat([y3, x2o], dim=1)
        y31 = F.elu(self.tl31(y3c))
        y32 = F.elu(self.tl32(y3c))
        y33 = F.elu(self.tl33(y3c))
        y3o = torch.cat([y31, y32, y33], dim=1)
        y4 = self.u3(y3o)
        #### Tr-Conv Block 4
        y4c = torch.cat([y4, x1o], dim=1)
        y41 = F.elu(self.tl41(y4c))
        y42 = F.elu(self.tl42(y4c))
        y43 = F.elu(self.tl43(y4c))
        y4o = torch.cat([y41, y42, y43, x], dim=1)
        #### Conv Layer Head 1
        y5 = F.elu(self.conv1(y4o))
        y6o = F.hardsigmoid(self.conv2(y5))
        y6 = self.mask(y6o)
        T,C,H,W = y6.shape
        return y6.view(1,T,C,H,W)

# %%
class Generator_Net(nn.Module):
    def __init__(self, in_channels=6):
        super().__init__()
        ###### C-Block Stacking ##########
        self.l11 = nn.Conv2d(in_channels, 64, 5, padding='same')
        self.l12 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=2)
        self.l13 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=5)
        self.a11 = nn.ELU()
        self.a12 = nn.ELU()
        self.a13 = nn.ELU()
        self.d1 = nn.MaxPool2d(2)
        self.l21 = nn.Conv2d(128, 64, 5, padding='same')
        self.l22 = nn.Conv2d(128, 32, 5, padding='same', dilation=2)
        self.l23 = nn.Conv2d(128, 32, 5, padding='same', dilation=5)
        self.a21 = nn.ELU()
        self.a22 = nn.ELU()
        self.a23 = nn.ELU()
        self.d2 = nn.MaxPool2d(2)
        self.l31 = nn.Conv2d(128, 128, 5, padding='same')
        self.l32 = nn.Conv2d(128, 64, 5, padding='same', dilation=2)
        self.l33 = nn.Conv2d(128, 64, 5, padding='same', dilation=5)
        self.a31 = nn.ELU()
        self.a32 = nn.ELU()
        self.a33 = nn.ELU()
        self.d3 = nn.MaxPool2d(2)
        self.l41 = nn.Conv2d(256, 128, 5, padding='same')
        self.l42 = nn.Conv2d(256, 64, 5, padding='same', dilation=2)
        self.l43 = nn.Conv2d(256, 64, 5, padding='same', dilation=5)
        self.a41 = nn.ELU()
        self.a42 = nn.ELU()
        self.a43 = nn.ELU()
        self.d4 = nn.MaxPool2d(2)
        self.l51 = nn.Conv2d(256, 256, 5, padding='same')
        self.l52 = nn.Conv2d(256, 128, 5, padding='same', dilation=2)
        self.l53 = nn.Conv2d(256, 128, 5, padding='same', dilation=5)
        self.a51 = nn.ELU()
        self.a52 = nn.ELU()
        self.a53 = nn.ELU()
        self.convBlstm = ConvBLSTM(512, 512, (5,5), 1, batch_first=True)
        self.u1 = nn.Upsample(scale_factor=2)
        ###### TC-Block Stacking ##########
        self.tl11 = nn.ConvTranspose2d(256+512, 128, 5, padding=2)
        self.tl12 = nn.ConvTranspose2d(256+512, 64, 5, dilation=2, padding=4)
        self.tl13 = nn.ConvTranspose2d(256+512, 64, 5, dilation=5, padding=10)
        self.ta11 = nn.ELU()
        self.ta12 = nn.ELU()
        self.ta13 = nn.ELU()
        self.u2 = nn.Upsample(scale_factor=2)
        self.tl21 = nn.ConvTranspose2d(256+256, 128, 5, padding=2)
        self.tl22 = nn.ConvTranspose2d(256+256, 64, 5, dilation=2, padding=4)
        self.tl23 = nn.ConvTranspose2d(256+256, 64, 5, dilation=5, padding=10)
        self.ta21 = nn.ELU()
        self.ta22 = nn.ELU()
        self.ta23 = nn.ELU()
        self.u3 = nn.Upsample(scale_factor=2)
        self.tl31 = nn.ConvTranspose2d(256+128, 64, 5, padding=2)
        self.tl32 = nn.ConvTranspose2d(256+128, 32, 5, padding=4, dilation=2)
        self.tl33 = nn.ConvTranspose2d(256+128, 32, 5, padding=10, dilation=5)
        self.ta31 = nn.ELU()
        self.ta32 = nn.ELU()
        self.ta33 = nn.ELU()
        self.u4 = nn.Upsample(scale_factor=2)
        self.tl41 = nn.ConvTranspose2d(128+128, 64, 5, padding=2)
        self.tl42 = nn.ConvTranspose2d(128+128, 32, 5, padding=4, dilation=2)
        self.tl43 = nn.ConvTranspose2d(128+128, 32, 5, padding=10, dilation=5)
        self.ta41 = nn.ELU()
        self.ta42 = nn.ELU()
        self.ta43 = nn.ELU()
        ###### Conv Layer Stacking ##########
        self.conv1 = nn.ConvTranspose2d(128+in_channels,8, 3, padding=1)
        self.conv2 = nn.ConvTranspose2d(8, 3, 3, padding=1)
        self.conva1 = nn.ELU()
        self.conva2 = nn.Hardsigmoid()

    def forward(self, x):
        B,T,C,H,W = x.shape
        x = x.view(B*T,C,H,W)
        #### Conv Block 1
        x11 = self.a11(self.l11(x))
        x12 = self.a12(self.l12(x))
        x13 = self.a13(self.l13(x))
        x1o = torch.cat([x11,x12,x13], dim=1)
        x1 = self.d1(x1o)
        #### Conv Block 2
        x21 = self.a21(self.l21(x1))
        x22 = self.a22(self.l22(x1))
        x23 = self.a23(self.l23(x1))
        x2o = torch.cat([x21,x22,x23], dim=1)
        x2 = self.d2(x2o)
        #### Conv Block 3
        x31 = self.a31(self.l31(x2))
        x32 = self.a32(self.l32(x2))
        x33 = self.a33(self.l33(x2))
        x3o = torch.cat([x31,x32,x33], dim=1)
        x3 = self.d3(x3o)
        #### Conv Block 4
        x41 = self.a41(self.l41(x3))
        x42 = self.a42(self.l42(x3))
        x43 = self.a43(self.l43(x3))
        x4o = torch.cat([x41,x42,x43], dim=1)
        x4 = self.d4(x4o)
        #### Conv Block 5
        x51 = self.a51(self.l51(x4))
        x52 = self.a52(self.l52(x4))
        x53 = self.a53(self.l53(x4))
        x5o = torch.cat([x51,x52,x53], dim=1)
        t,n,h,w = x5o.shape
        x5 = x5o.view(1, t, n, h, w)
        #### ConvBiLSTM
        x_temp = self.convBlstm(x5,torch.flip(x5,[1]))
        _, t,n,h,w = x_temp.shape
        x_resized = x_temp.view(t,n,h,w)
        x_lstm = self.u1(x_resized)       
        #### Tr-Conv Block 1
        y1c = torch.cat([x_lstm, x4o], dim=1)
        y11 = self.ta11(self.tl11(y1c))
        y12 = self.ta12(self.tl12(y1c))
        y13 = self.ta13(self.tl13(y1c))
        y1o = torch.cat([y11, y12, y13], dim=1)
        y2 = self.u2(y1o)
        #### Tr-Conv Block 2
        y2c = torch.cat([y2, x3o], dim=1)
        y21 = self.ta21(self.tl21(y2c))
        y22 = self.ta22(self.tl22(y2c))
        y23 = self.ta23(self.tl23(y2c))
        y2o = torch.cat([y21, y22, y23], dim=1)
        y3 = self.u3(y2o)
        #### Tr-Conv Block 3
        y3c = torch.cat([y3, x2o], dim=1)
        y31 = self.ta31(self.tl31(y3c))
        y32 = self.ta32(self.tl32(y3c))
        y33 = self.ta33(self.tl33(y3c))
        y3o = torch.cat([y31, y32, y33], dim=1)
        y4 = self.u3(y3o)
        #### Tr-Conv Block 4
        y4c = torch.cat([y4, x1o], dim=1)
        y41 = self.ta41(self.tl41(y4c))
        y42 = self.ta42(self.tl42(y4c))
        y43 = self.ta43(self.tl43(y4c))
        y4o = torch.cat([y41, y42, y43, x], dim=1)
        #### Conv Layer Head 1
        y5 = self.conva1(self.conv1(y4o))
        y6 = self.conva2(self.conv2(y5))
        T,C,H,W = y6.shape
        return y6.view(1,T,C,H,W)

# %%
from Module.Normalization import SpectralNorm
from Module.SpectralConvLSTM import SpectralConvBLSTM
class Discriminator(nn.Module):
    def __init__(self, in_channels=3):
        super().__init__()
        self.pre_conv = nn.Sequential(SpectralNorm(nn.Conv2d(in_channels,64,3,padding='same')), 
                                       nn.LeakyReLU(),
                                       SpectralNorm(nn.Conv2d(64,128,3,padding='same')), 
                                       nn.LeakyReLU(),
                                       SpectralNorm(nn.Conv2d(128,128,3,padding='same')),
                                       nn.LeakyReLU(),
                                       nn.AvgPool2d(2)
                                      )
        self.lstm_network_1 = SpectralConvBLSTM(128, 256, (3,3), 1, batch_first=True)
        self.a1 = nn.LeakyReLU()
        self.pool1 = nn.AvgPool2d(2)
        self.lstm_network_2 = SpectralConvBLSTM(256, 256, (3,3), 1, batch_first=True)
        self.a2 = nn.LeakyReLU()
        self.pool2 = nn.AvgPool2d(2)
        self.lstm_network_3 = SpectralConvBLSTM(256, 512, (3,3), 1, batch_first=True)
        self.a3 = nn.LeakyReLU()
        self.pool3 = nn.AvgPool2d(2)
        self.linear = SpectralNorm(nn.Linear(512, 1))
    def forward(self,x):
        B,T,C,H,W = x.shape
        out = self.pre_conv(x.view(B*T,C,H,W))
        _,C,H,W = out.shape
        out = out.view(B,T,C,H,W)
        out = self.a1(self.lstm_network_1(out, torch.flip(out,[1])))
        B,T,C,H,W = out.shape
        out = self.pool1(out.view(B*T,C,H,W))
        _,C,H,W = out.shape
        out = out.view(B,T,C,H,W)
        out = self.a2(self.lstm_network_2(out, torch.flip(out,[1])))
        B,T,C,H,W = out.shape
        out = self.pool2(out.view(B*T,C,H,W))
        _,C,H,W = out.shape
        out = out.view(B,T,C,H,W)
        out = self.a3(self.lstm_network_3(out, torch.flip(out,[1])))
        B,T,C,H,W = out.shape
        out = self.pool3(out.view(B*T,C,H,W)).view(B*T,C,-1)
        out = out.sum(2)
        out = self.linear(out).squeeze(1)
        return out
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5072/465499921.py in <module>
# ----> 1 from Module.Normalization import SpectralNorm
#       2 from Module.SpectralConvLSTM import SpectralConvBLSTM
#       3 class Discriminator(nn.Module):
#       4     def __init__(self, in_channels=3):
#       5         super().__init__()
#
# D:\shared_folder\Module\Normalization.py in <module>
#       3 from torch.nn import Parameter
#       4
# ----> 5 from tensorboardX import SummaryWriter
#       6
#       7 def l2normalize(v, eps=1e-12):
#
# ModuleNotFoundError: No module named 'tensorboardX'

# %%
from torchsummary import summary
#model = Mask_Generator_Net(3)
#model = Generator_Net(3)
#y = model(torch.rand((5,3,240,320)))
#model = Discriminator()
model = Discriminator_space()
y = model(torch.rand((1,2,3,240,320)))
y.shape
# Out:
# torch.Size([2])

# %%
from Module.Normalization import SpectralNorm
from Module.SpectralConvLSTM import SpectralConvBLSTM
class Discriminator_space(nn.Module):
    def __init__(self, in_channels=3):
        super().__init__()
        self.pre_conv = nn.Sequential(SpectralNorm(nn.Conv2d(in_channels,64,3,padding='same')), 
                                       nn.LeakyReLU(),
                                       SpectralNorm(nn.Conv2d(64,128,3,padding='same')), 
                                       nn.LeakyReLU(),
                                       SpectralNorm(nn.Conv2d(128,128,3,padding='same')),
                                       nn.LeakyReLU(),
                                       nn.AvgPool2d(2),
                                      SpectralNorm(nn.Conv2d(128,256,3,padding='same')),
                                       nn.LeakyReLU(),
                                       nn.AvgPool2d(2),
                                      SpectralNorm(nn.Conv2d(256,256,3,padding='same')),
                                       nn.LeakyReLU(),
                                       nn.AvgPool2d(2),
                                      SpectralNorm(nn.Conv2d(256,512,3,padding='same')),
                                       nn.LeakyReLU(),
                                       nn.AvgPool2d(2)
                                      )
        self.linear = SpectralNorm(nn.Linear(512, 1))
    def forward(self,x):
        B,T,C,H,W = x.shape
        out = x.view(-1,C,H,W)
        out = self.pre_conv(out)
        BT,C,_,_ = out.shape
        out = out.view(BT,C,-1)
        out = out.sum(2)
        out = self.linear(out).squeeze(1)
        return out

# %%
model1 = Mask_Generator_Net()
model2 = Generator_Net()

# %%
dummy = filter(lambda p: p.requires_grad, list(model1.parameters())+list(model2.parameters()))

# %%
print(lambda p: p.requires_grad, model1.parameters())
# Out:
# <function <lambda> at 0x7f3c70b7fb50> <generator object Module.parameters at 0x7f3c7017eab0>

# %%
import numpy as np
a = torch.Tensor(np.arange(40)).view(1,2,1,4,5)

# %%
b = a.repeat(1,1,3,1,1)

# %%
len(training_data)
# Out:
# 287

# %%
import json

# %%
f = open('./Dataset/UCF101/annotations/ucf101_01.json')
  
# returns JSON object as 
# a dictionary
data = json.load(f)

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

class Binarization(nn.Module):
    def __init__(self):
        super().__init__()

    def forward(self,x):
        return torch.round(x)

    def backward(self, x):
        return x

class Mask_Generator_Net(nn.Module):
    def __init__(self, in_channels=3):
        super().__init__()
        ###### C-Block Stacking ##########
        self.l11 = nn.Conv2d(in_channels, 32, 5, padding='same')
        self.l12 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=2)
        self.d1 = nn.MaxPool2d(2)
        self.l21 = nn.Conv2d(64, 32, 5, padding='same')
        self.l22 = nn.Conv2d(64, 32, 5, padding='same', dilation=2)
        self.d2 = nn.MaxPool2d(2)
        self.l31 = nn.Conv2d(64, 64, 5, padding='same')
        self.l32 = nn.Conv2d(64, 64, 5, padding='same', dilation=2)
        self.d3 = nn.MaxPool2d(2)
        self.l41 = nn.Conv2d(128, 128, 5, padding='same')
        self.l42 = nn.Conv2d(128, 128, 5, padding='same', dilation=2)
        self.d4 = nn.MaxPool2d(2)
        self.l51 = nn.Conv2d(256, 256, 5, padding='same')
        self.l52 = nn.Conv2d(256, 256, 5, padding='same', dilation=2)
        self.convBlstm = ConvBLSTM(512, 512, (5,5), 1, batch_first=True)
        self.u1 = nn.Upsample(scale_factor=2)
        ###### TC-Block Stacking ##########
        self.tl11 = nn.ConvTranspose2d(256+512, 128, 5, padding=2)
        self.tl12 = nn.ConvTranspose2d(256+512, 128, 5, dilation=2, padding=4)
        self.u2 = nn.Upsample(scale_factor=2)
        self.tl21 = nn.ConvTranspose2d(128+256, 64, 5, padding=2)
        self.tl22 = nn.ConvTranspose2d(128+256, 64, 5, dilation=2, padding=4)
        self.u3 = nn.Upsample(scale_factor=2)
        self.tl31 = nn.ConvTranspose2d(64+128, 32, 5, padding=2)
        self.tl32 = nn.ConvTranspose2d(64+128, 32, 5, padding=4, dilation=2)
        self.u4 = nn.Upsample(scale_factor=2)
        self.tl41 = nn.ConvTranspose2d(64+64, 32, 5, padding=2)
        self.tl42 = nn.ConvTranspose2d(64+64, 32, 5, padding=4, dilation=2)
        ###### Conv Layer Stacking ##########
        self.conv1 = nn.ConvTranspose2d(64+in_channels,8, 3, padding=1)
        self.conv2 = nn.ConvTranspose2d(8, 1, 3, padding=1)
        self.mask = Binarization()

    def forward(self, x):
        #### Conv Block 1
        B,T,C,H,W = x.shape
        x = x.view(B*T,C,H,W)
        temp1 = F.elu(self.l11(x))
        temp2 = F.elu(self.l12(x))
        x1o = torch.cat([temp1,temp2], dim=1)
        out = self.d1(x1o)
        #### Conv Block 2
        temp1 = F.elu(self.l21(out))
        temp2 = F.elu(self.l22(out))
        x2o = torch.cat([temp1,temp2], dim=1)
        out = self.d2(x2o)
        #### Conv Block 3
        temp1 = F.elu(self.l31(out))
        temp2 = F.elu(self.l32(out))
        x3o = torch.cat([temp1,temp2], dim=1)
        out = self.d3(x3o)
        #### Conv Block 4
        temp1 = F.elu(self.l41(out))
        temp2 = F.elu(self.l42(out))
        x4o = torch.cat([temp1,temp2], dim=1)
        out = self.d4(x4o)
        #### Conv Block 5
        temp1 = F.elu(self.l51(out))
        temp2 = F.elu(self.l52(out))
        x5o = torch.cat([temp1,temp2], dim=1)
        t,n,h,w = x5o.shape
        out = x5o.view(1, t, n, h, w)
        #### ConvBiLSTM
        out = self.convBlstm(out,torch.flip(out,[1]))
        _, t,n,h,w = out.shape
        out = out.view(t,n,h,w)
        out = self.u1(out)       
        #### Tr-Conv Block 1
        out = torch.cat([out, x4o], dim=1)
        temp1 = F.elu(self.tl11(out))
        temp2 = F.elu(self.tl12(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u2(out)
        #### Tr-Conv Block 2
        out = torch.cat([out, x3o], dim=1)
        temp1 = F.elu(self.tl21(out))
        temp2 = F.elu(self.tl22(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u3(out)
        #### Tr-Conv Block 3
        out = torch.cat([out, x2o], dim=1)
        temp1 = F.elu(self.tl31(out))
        temp2 = F.elu(self.tl32(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u3(out)
        #### Tr-Conv Block 4
        out = torch.cat([out, x1o], dim=1)
        temp1 = F.elu(self.tl41(out))
        temp2 = F.elu(self.tl42(out))
        out = torch.cat([temp1, temp2, x], dim=1)
        #### Conv Layer Head 1
        out = F.elu(self.conv1(out))
        out = F.hardsigmoid(self.conv2(out))
        out = self.mask(out)
        T,C,H,W = out.shape
        return out.view(1,T,C,H,W)

# %%
class Generator_Net(nn.Module):
    def __init__(self, in_channels=4):
        super().__init__()
        ###### C-Block Stacking ##########
        self.l11 = nn.Conv2d(in_channels, 32, 5, padding='same')
        self.l12 = nn.Conv2d(in_channels, 32, 5, padding='same', dilation=2)
        self.d1 = nn.MaxPool2d(2)
        self.l21 = nn.Conv2d(64, 32, 5, padding='same')
        self.l22 = nn.Conv2d(64, 32, 5, padding='same', dilation=2)
        self.d2 = nn.MaxPool2d(2)
        self.l31 = nn.Conv2d(64, 64, 5, padding='same')
        self.l32 = nn.Conv2d(64, 64, 5, padding='same', dilation=2)
        self.d3 = nn.MaxPool2d(2)
        self.l41 = nn.Conv2d(128, 128, 5, padding='same')
        self.l42 = nn.Conv2d(128, 128, 5, padding='same', dilation=2)
        self.d4 = nn.MaxPool2d(2)
        self.l51 = nn.Conv2d(256, 256, 5, padding='same')
        self.l52 = nn.Conv2d(256, 256, 5, padding='same', dilation=2)
        self.convBlstm = ConvBLSTM(512, 512, (5,5), 1, batch_first=True)
        self.u1 = nn.Upsample(scale_factor=2)
        ###### TC-Block Stacking ##########
        self.tl11 = nn.ConvTranspose2d(256+512, 128, 5, padding=2)
        self.tl12 = nn.ConvTranspose2d(256+512, 128, 5, dilation=2, padding=4)
        self.u2 = nn.Upsample(scale_factor=2)
        self.tl21 = nn.ConvTranspose2d(128+256, 64, 5, padding=2)
        self.tl22 = nn.ConvTranspose2d(128+256, 64, 5, dilation=2, padding=4)
        self.u3 = nn.Upsample(scale_factor=2)
        self.tl31 = nn.ConvTranspose2d(64+128, 32, 5, padding=2)
        self.tl32 = nn.ConvTranspose2d(64+128, 32, 5, padding=4, dilation=2)
        self.u4 = nn.Upsample(scale_factor=2)
        self.tl41 = nn.ConvTranspose2d(64+64, 32, 5, padding=2)
        self.tl42 = nn.ConvTranspose2d(64+64, 32, 5, padding=4, dilation=2)
        ###### Conv Layer Stacking ##########
        self.conv1 = nn.ConvTranspose2d(64+in_channels,8, 3, padding=1)
        self.conv2 = nn.ConvTranspose2d(8, 3, 3, padding=1)

    def forward(self, x):
        #### Conv Block 1
        B,T,C,H,W = x.shape
        x = x.view(B*T,C,H,W)
        temp1 = F.elu(self.l11(x))
        temp2 = F.elu(self.l12(x))
        x1o = torch.cat([temp1,temp2], dim=1)
        out = self.d1(x1o)
        #### Conv Block 2
        temp1 = F.elu(self.l21(out))
        temp2 = F.elu(self.l22(out))
        x2o = torch.cat([temp1,temp2], dim=1)
        out = self.d2(x2o)
        #### Conv Block 3
        temp1 = F.elu(self.l31(out))
        temp2 = F.elu(self.l32(out))
        x3o = torch.cat([temp1,temp2], dim=1)
        out = self.d3(x3o)
        #### Conv Block 4
        temp1 = F.elu(self.l41(out))
        temp2 = F.elu(self.l42(out))
        x4o = torch.cat([temp1,temp2], dim=1)
        out = self.d4(x4o)
        #### Conv Block 5
        temp1 = F.elu(self.l51(out))
        temp2 = F.elu(self.l52(out))
        x5o = torch.cat([temp1,temp2], dim=1)
        t,n,h,w = x5o.shape
        out = x5o.view(1, t, n, h, w)
        #### ConvBiLSTM
        out = self.convBlstm(out,torch.flip(out,[1]))
        _, t,n,h,w = out.shape
        out = out.view(t,n,h,w)
        out = self.u1(out)       
        #### Tr-Conv Block 1
        out = torch.cat([out, x4o], dim=1)
        temp1 = F.elu(self.tl11(out))
        temp2 = F.elu(self.tl12(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u2(out)
        #### Tr-Conv Block 2
        out = torch.cat([out, x3o], dim=1)
        temp1 = F.elu(self.tl21(out))
        temp2 = F.elu(self.tl22(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u3(out)
        #### Tr-Conv Block 3
        out = torch.cat([out, x2o], dim=1)
        temp1 = F.elu(self.tl31(out))
        temp2 = F.elu(self.tl32(out))
        out = torch.cat([temp1, temp2], dim=1)
        out = self.u3(out)
        #### Tr-Conv Block 4
        out = torch.cat([out, x1o], dim=1)
        temp1 = F.elu(self.tl41(out))
        temp2 = F.elu(self.tl42(out))
        out = torch.cat([temp1, temp2, x], dim=1)
        #### Conv Layer Head 1
        out = F.elu(self.conv1(out))
        out = F.hardsigmoid(self.conv2(out))
        T,C,H,W = out.shape
        return out.view(1,T,C,H,W)

# %%
from torchsummary import summary
summary(Mask_Generator_Net(3).cpu(),(1,3,240,320), device="cpu")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12044/465430550.py in <module>
#       1 from torchsummary import summary
# ----> 2 summary(Mask_Generator_Net(3).cpu(),(1,3,240,320), device="cpu")
#
# ~\anaconda3\lib\site-packages\torchsummary\torchsummary.py in summary(model, input_size, batch_size, device)
#      70     # make a forward pass
#      71     # print(x.shape)
# ---> 72     model(*x)
#      73
#      74     # remove these hooks
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1100         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1101                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1102             return forward_call(*input, **kwargs)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from importlib import reload

# %load_ext autoreload

# %autoreload 2

# %%
# %reload_ext autoreload

# %%
# %pip install tensorboardX
# %pip install av
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 125 kB 4.2 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 28.2 MB 1.4 MB/s
# ...

# %%
# !wget --no-check-certificate https://www.crcv.ucf.edu/data/UCF101/UCF101.rar
# !unrar x "/content/UCF101.rar"
# !rm -rf "/content/UCF101.rar"
# !wget --no-check-certificate https://www.crcv.ucf.edu/data/UCF101/UCF101TrainTestSplits-RecognitionTask.zip
# !unzip /content/UCF101TrainTestSplits-RecognitionTask.zip
# !rm -rf /content/UCF101TrainTestSplits-RecognitionTask.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    UCF-101/PlayingPiano                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# Out:
# unzip:  cannot find or open /content/UCF101TrainTestSplits-RecognitionTask.zip, /content/UCF101TrainTestSplits-RecognitionTask.zip.zip or /content/UCF101TrainTestSplits-RecognitionTask.zip.ZIP.

# %%
# %cd '/content/drive/MyDrive/Colab Notebooks/PROJ_AB_Run2'
# Out:
# /content/drive/MyDrive/Colab Notebooks/PROJ_AB_Run2

# %%
import os
import shutil

# %%
f = open("./Dataset/annotations/remove1.txt", "r")
a = f.read()

# %%
b = a.split("\n")

folders = []
for entry in b:
  first,act = entry.split(" ")
  folders.append(act)

# %%
root_path = "/content/UCF-101"
for folder in folders:
  pth = os.path.join(root_path,folder)
  shutil.rmtree(pth)

# %%
from trainer3 import Trainer
# from tester import Tester
from data_loader import Data_Loader
from torch.backends import cudnn
from utils import make_folder
from parameter import get_parameters

import os
import torch

##### Import libary for dataloader #####
##### https://github.com/kenshohara/3D-ResNets-PyTorch/blob/master/main.py
from Dataloader.transform.spatial_transforms import (
    Compose, VideoRandomCrop, RandomHorizontalFlip, ToTensor)
# from Dataloader.transform.temporal_transforms import LoopPadding, TemporalRandomCrop
# from Dataloader.transform.target_transforms import ClassLabel, VideoID
# from Dataloader.transform.target_transforms import Compose as TargetCompose
from Dataloader.dataloader import get_training_set, get_validation_set, get_test_set
from Dataloader.mean import get_mean
from torchvision.datasets import UCF101

# %%
class CONFIG():
    def __init__(self):
        self.model='dvd-gan'
        self.adv_loss='hinge'
        self.imsize=128
        self.g_num=5
        self.g_chn=32
        self.z_dim=120
        self.ds_chn=32 # SpatialDiscriminator channel
        self.dt_chn=32 # TemporalDiscriminator channel
        self.g_conv_dim=64
        self.d_conv_dim=64
        self.lambda_gp=10.0
        self.lr_schr='const'
        self.version=''

            # Training setting
        self.total_epoch=10
        self.d_iters=1
        self.g_iters=1
        self.batch_size=2
        self.num_workers=1
        self.g_lr=5e-1
        self.d_lr=1e-5
        self.lr_decay=0.9999
        self.beta1=0.0
        self.beta2=0.9

            # using pretrained
        self.pretrained_model = 37000

            # Misc
        self.train=True
        self.parallel=False
        self.gpus=["0"]
        self.dataset='ucf101'
        self.use_tensorboard=False
        self.n_class=101
        self.k_sample=64
        self.n_frames=24
        self.test_batch_size=8

            # Path
        self.image_path='./data'
        self.log_path='./logs'
        self.model_save_path='/content/models'
        self.sample_path='./samples'

            # epoch size
        self.log_epoch=1
        self.sample_epoch=1
        self.model_save_epoch=1000

            # Dataloader
        self.norm_value=255
        self.no_mean_norm=True
        self.std_norm=False
        self.mean_dataset='activitynet'
        self.root_path='/tmp4/potter/UCF101'
        self.video_path='videos_jpeg'
        self.annotation_path='annotations/ucf101_01.json'
        self.train_crop='none'
        self.sample_size=64

        self.initial_scale=1.0
        self.n_scales=5
        self.scale_step=0.84089641525
        self.density = 0.05

# %%
config = CONFIG()


config.dataset = 'ucf101'
config.video_path = "videos_jpeg"
config.adv_loss = 'hinge'
config.parallel = True
config.gpus = ["0"]
config.num_workers = 1
config.use_tensorboard = True 
config.ds_chn = 32 
config.dt_chn = 32 
config.g_chn = 32 
config.n_frames = 8 
config.k_sample = 4 
config.batch_size = 2
config.g_lr = 5e-5 
config.d_lr = 1e-5 
config.n_class = 1 
config.lr_schr = "const"
config.n_class = 2
config.root_path = "/content/UCF-101"
config.annotation_path = "/content/ucfTrainTestlist"
config.log_path = "./output1/logs"
config.model_save_path = "./outputs1/modelsZ"
config.sample_path = "./outputs1/samples"
config.train_crop == 'none'
# Out:
# True

# %%
def custom_collate(batch):
    filtered_batch = []
    for video, _, _ in batch:
        filtered_batch.append(video)
    return torch.utils.data.dataloader.default_collate(filtered_batch)



cudnn.benchmark = True

##### Dataloader #####
config.mean = get_mean(config.norm_value, dataset=config.mean_dataset)

# if config.no_mean_norm and not config.std_norm:
#     norm_method = Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])
# elif not config.std_norm:
#     norm_method = Normalize(config.mean, [1, 1, 1])

if config.train:
    spatial_transform = Compose([ToTensor(), VideoRandomCrop(128), RandomHorizontalFlip()]) 
    temporal_transform = None
    target_transform = None

    print("="*30,"\nLoading data...")
    training_data = UCF101("/content/UCF-101", "/content/ucfTrainTestlist", frames_per_clip=20,
                       step_between_clips=1, train=True, output_format="TCHW", transform=spatial_transform)
    train_loader = torch.utils.data.DataLoader(
            training_data,
            batch_size=config.batch_size,
            collate_fn=custom_collate,
            shuffle=True,
            num_workers=config.num_workers,
            pin_memory=True)
else:
    spatial_transform = Compose([
        Scale(config.sample_size),
        CenterCrop(config.sample_size),
        ToTensor(config.norm_value), norm_method
    ])
    temporal_transform = LoopPadding(config.n_frames)
    target_transform = ClassLabel()
    validation_data = get_validation_set(
        config, spatial_transform, temporal_transform, target_transform)
    val_loader = torch.utils.data.DataLoader(
        validation_data,
        batch_size=config.batch_size,
        collate_fn=custom_collate,
        shuffle=False,
        num_workers=config.num_workers,
        pin_memory=True)
# Out:
# ...
# Loading data...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
make_folder(config.model_save_path, config.version)
make_folder(config.log_path, config.version)

# %%
config.total_epoch=10
trainer = Trainer(train_loader, config) 
trainer.train()
# Out:
# ...
# Build_model...
# Model building done!
# load_pretrained_model...
# loaded trained models (step: 37000)..!
# Inside the trainer!
# /usr/local/lib/python3.7/dist-packages/torchvision/io/video.py:162: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")
# Iterator created!
# steps per epoch: 7482
# ...
# Start training...
# DS_Loss:tensor(1.9945, device='cuda:0', grad_fn=<AddBackward0>)
# 37200
# DS_Loss:tensor(2.0001, device='cuda:0', grad_fn=<AddBackward0>)
# DT_Loss:tensor(2.0029, device='cuda:0', grad_fn=<AddBackward0>)
# Selected Density:tensor(-0.0003, device='cuda:0')
# DS_Loss:tensor(0.9785, device='cuda:0', grad_fn=<MeanBackward0>) DT_Loss:tensor(0.8266, device='cuda:0', grad_fn=<MeanBackward0>) MSE_Loss:tensor(0.0016, device='cuda:0', grad_fn=<MseLossBackward0>) Density_Loss:tensor(0.0003, device='cuda:0')
# ...

# %%
def custom_collate(batch):
    filtered_batch = []
    for video, _, _ in batch:
        filtered_batch.append(video)
    return torch.utils.data.dataloader.default_collate(filtered_batch)

spatial_transform = Compose([ToTensor(), VideoRandomCrop(128), RandomHorizontalFlip()]) 
temporal_transform = None
target_transform = None

print("="*30,"\nLoading data...")
test_data = UCF101("/content/UCF-101", "/content/drive/MyDrive/Colab Notebooks/PROJ_AB_Run2/Dataset/annotations", frames_per_clip=20,
                    step_between_clips=1, train=False, output_format="TCHW", transform=spatial_transform)
test_loader = torch.utils.data.DataLoader(
        test_data,
        batch_size=2,
        collate_fn=custom_collate,
        shuffle=True,
        num_workers=1,
        pin_memory=True)
# Out:
# ...
# Loading data...
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
from Module.Generator import Generator, Mask_Generator_Net, Generator_Net
from Module.Discriminators import SpatialDiscriminator, TemporalDiscriminator, DiscriminatorLSTM, Discriminator_space

G = Generator_Net(7).cuda()
#mask_G = Mask_Generator_Net(6).cuda()

G.load_state_dict(torch.load(os.path.join(
    "./outputs/modelsZ", '{}_G.pth'.format(31000))))
#mask_G.load_state_dict(torch.load(os.path.join(
#   "./outputs_center_c/modelsZ", '{}_mask_G.pth'.format(28000))))
# Out:
# <All keys matched successfully>

# %%
from torchvision.utils import save_image, make_grid
from torch.nn import MSELoss

avg_mse = 0
for i in range(len(test_data)):

    real_videos,_,_ = test_data[i]
    t,c,h,w = real_videos.shape
    real_videos = real_videos.view(-1,t,c,h,w).cuda()
    
    seed1 = torch.rand((1,t,c,h,w)).cuda()
    video_mask = torch.rand((1,t,1,h,w))
    video_mask = ((video_mask<0.01)*1.0).cuda()
    #video_mask = mask_G(torch.cat((real_videos, seed1), 2))
    torch.cuda.empty_cache()

    #print("Mask generated")
    # ============== Create Masked Video ============== #

    B,T,C,H,W = video_mask.shape
    masked_video = video_mask.repeat(1,1,3,1,1) * real_videos
    torch.cuda.empty_cache()

    # ============== Frame Generator ================= #

    seed2 = torch.rand((1,t,c,h,w)).cuda()
    #print(masked_video.shape)
    #print(video_mask.shape)
    #print(seed2.shape)
    #print(new_inp.shape)
    fake_video = G(torch.cat((masked_video, video_mask, seed2), 2))
    mse = MSELoss()(real_videos,fake_video)
    avg_mse+=mse.item()
    # if(mse<min_mse):
    #     min_mse = mse
    #     min_idx = i
    if(i%200==0):
      print(str(i)+" Avg MSE:"+str(avg_mse/(i+1)))
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/io/video.py:162: UserWarning: The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.
#   warnings.warn("The pts_unit 'pts' gives wrong results. Please use pts_unit 'sec'.")
# Streaming output truncated to the last 5000 lines.
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# torch.Size([1, 20, 1, 128, 128])
# torch.Size([1, 20, 3, 128, 128])
# ...

# %%
def convert_to_imgs(tensor, path, msg):
    frames = tensor.shape[1]
    for f in range(frames):
        save_image(tensor[0][f], os.path.join(path, msg+"_%d.png" % (f)))

# %%
path = "/content/drive/MyDrive/Colab Notebooks/PROJ_AB_Run2/Images"
convert_to_imgs(real_videos, path, "Real_vid_31k_")

# %%
convert_to_imgs(masked_video, path, "Masked_vid_31k_")
convert_to_imgs(fake_video, path, "Fake_vid_31k_")

# %%
mse
# Out:
# tensor(0.0216, device='cuda:0', grad_fn=<MseLossBackward0>)

# %%
len(test_data)
# Out:
# 6639

# %%
avg_mse/len(test_data)
# Out:
# 0.018562657943062482
